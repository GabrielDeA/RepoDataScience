# %% [markdown]
# ## 1. Distribution (univariate)
#
# Chosen variable: *fertility_rate_hist*
#
# - h0: Skewness is close to 0 (symmetric), considering all time periods
# - h1: Nigerian fertility rate is higher than other countries in the MENA region

# %% [markdown]
# ## 2. Relationship (bivariate)
# Chosen variables: *fertility_rate_hist* and *child_mortality_rate*
#
# - h0: There is a association  between variables
# - h1: The relation in positive
