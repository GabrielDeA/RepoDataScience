# %%
#Utilizaremos variáveis para fazer suposições dentro do dataset

# %%
#aqui planeja utilizar uma variável de mortalidade infantil e deduzir que em países

# %%
#aqui planejo utilizar uma variável de fecundidade e deduzir que no japão tem os menores valores de fecundidade.
'''
Parte 01.
Precisamos pegar uma variável e fazer uma suposição
Perguntas:
1.Como você descreveria sua distribuição? (simétrica, distorcida, presença de pontos fora da curva)
2.proponha uma hipotese sobre sua distribuição
'''
# Out:
# ''

# %%
"""
Parte 02.
Precisamos selecionar duas variaveis e descrever o relacionamento entre elas
"""
